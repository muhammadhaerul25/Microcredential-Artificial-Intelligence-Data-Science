# %%
import pandas as pd

# %%
df = pd.read_csv("ispu.csv")
df
# Out:
#         tanggal                           stasiun pm10 pm25 so2  co  o3 no2  \
# 0    2021-04-01                DKI1 (Bunderan HI)   26   42  22  11  13  19
# 1    2021-04-02                DKI1 (Bunderan HI)   41   54  27  11  17  19
# 2    2021-04-03                DKI1 (Bunderan HI)   25   42  20   8  18  22
# 3    2021-04-04                DKI1 (Bunderan HI)   57   78  21  23  14  33
# 4    2021-04-05                DKI1 (Bunderan HI)   52   69  22  15  18  27
# ..          ...                               ...  ...  ...  ..  ..  ..  ..
# 750  2021-05-27  DKI5 (Kebon Jeruk) Jakarta Barat   34   61  32   5  20  11
# 751  2021-05-28  DKI5 (Kebon Jeruk) Jakarta Barat   49   77  37   8  20  19
# 752  2021-05-29  DKI5 (Kebon Jeruk) Jakarta Barat   54   88  37  11  19  29
# 753  2021-05-30  DKI5 (Kebon Jeruk) Jakarta Barat   46   66  24  15  18  29
# 754  2021-05-31  DKI5 (Kebon Jeruk) Jakarta Barat   52   82  21  11  27  18
#
#      max critical categori
# 0     42     PM25     BAIK
# ...

# %%
df.groupby('categori').size()
# Out:
# categori
# BAIK              125
# SEDANG            558
# TIDAK ADA DATA      7
# TIDAK SEHAT        65
# dtype: int64

# %%
df.isna().sum()
# Out:
# tanggal      0
# stasiun      0
# pm10         0
# pm25        62
# so2          0
# co           0
# o3           0
# no2          0
# max          0
# critical     7
# categori     0
# dtype: int64

# %%
df.isna().sum()
# Out:
# tanggal       0
# stasiun     305
# pm10          0
# pm25         62
# so2           0
# co            0
# o3            0
# no2           0
# max           0
# critical      5
# categori      1
# location    605
# dtype: int64

# %%
df = pd.read_csv("ispu (8).csv")
df
# Out:
#         tanggal                           stasiun pm10 pm25 so2  co  o3 no2  \
# 0    2021-04-01                DKI1 (Bunderan HI)   26   42  22  11  13  19
# 1    2021-04-02                DKI1 (Bunderan HI)   41   54  27  11  17  19
# 2    2021-04-03                DKI1 (Bunderan HI)   25   42  20   8  18  22
# 3    2021-04-04                DKI1 (Bunderan HI)   57   78  21  23  14  33
# 4    2021-04-05                DKI1 (Bunderan HI)   52   69  22  15  18  27
# ..          ...                               ...  ...  ...  ..  ..  ..  ..
# 145  2021-04-26  DKI5 (Kebon Jeruk) Jakarta Barat   52   82  28  10  26  19
# 146  2021-04-27  DKI5 (Kebon Jeruk) Jakarta Barat   56   95  33   9  28  18
# 147  2021-04-28  DKI5 (Kebon Jeruk) Jakarta Barat   49   81  21  10  26  22
# 148  2021-04-29  DKI5 (Kebon Jeruk) Jakarta Barat   43   73  22  14  26  25
# 149  2021-04-30  DKI5 (Kebon Jeruk) Jakarta Barat   52   83  23  12  28  23
#
#      max critical categori
# 0     42     PM25     BAIK
# ...

# %%
df14.groupby('categori').size()
# Out:
# categori
# BAIK                5
# SEDANG            135
# TIDAK ADA DATA      1
# TIDAK SEHAT        14
# dtype: int64
